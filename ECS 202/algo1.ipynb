# %%
# insertion sort
def insertion_sort(arr):
    for i in range(len(arr)):
        j = i
        while j > 0 and arr[j] < arr[j-1]:
            arr[j], arr[j-1] = arr[j-1], arr[j] # swapping the places.
            j -= 1  
    return arr

# %%
insertion_sort([3, 2, 1, 5, 4])
# Out:
# [1, 2, 3, 4, 5]

# %%
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quicksort(left) + middle + quicksort(right)

# Example usage
print(quicksort([3, 6, 8, 10, 1, 2, 1]))
# plotting the complexity of the algorithm
import matplotlib.pyplot as plt
import time
import random
import numpy as np
def plot_complexity(func, n):
    times = []
    for i in range(1, n):
        arr = [random.randint(0, 1000) for _ in range(i)]  # Increasing number of elements
        start = time.time()
        func(arr)
        end = time.time()
        times.append(end - start)
    
    # Plot the results
    plt.plot(np.arange(1, n), times)  # x-axis is the number of elements
    plt.xlabel('Number of elements (n)')
    plt.ylabel('Time (seconds)')
    plt.title('QuickSort Time Complexity')
    plt.show()

plot_complexity(quicksort, 100)
# Out:
# [1, 1, 2, 3, 6, 8, 10]
